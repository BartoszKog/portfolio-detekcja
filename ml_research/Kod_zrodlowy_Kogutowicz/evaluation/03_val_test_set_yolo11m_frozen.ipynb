# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.230 🚀 Python-3.10.19 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 8192MiB)
# Setup complete ✅ (12 CPUs, 7.7 GB RAM, 77.9/1006.9 GB disk)

# %%
from ultralytics import YOLO
from pathlib import Path
from ultralytics.utils.plotting import plot_results

# %% [markdown]
# # Wykresy treningu
#
# W fazie treningu nie zostały utworzone

# %%
plot_results("training_results/yolo11m_freeze10_epochs35/results.csv")

# %% [markdown]
# # Walidacja na zbiorze testowym

# %%
model = YOLO("training_results/yolo11m_freeze10_epochs35/weights/best.pt")
metrics = model.val(
    split='test',
    batch=2,
    imgsz = 1024,
    project = 'results_testowe',
    name = 'wyniki_test_yolomfreeze10'
)
# Out:
# Ultralytics 8.3.230 🚀 Python-3.10.19 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 8192MiB)
# YOLO11m-obb summary (fused): 134 layers, 20,879,254 parameters, 0 gradients, 71.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 305.0±157.5 MB/s, size: 378.7 KB)
# val: Scanning /home/bartos/projekty_yolo/detekcja_pojazdow/data_1024_res/labels/test.cache... 2768 images, 741 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3509/3509 6.1Mit/s 0.0s0s
# val: /home/bartos/projekty_yolo/detekcja_pojazdow/data_1024_res/images/test/2008-11-27-Muenchen-Verkehr-links-ys5z0038__1024__0___1536.jpg: 1 duplicate labels removed
# val: /home/bartos/projekty_yolo/detekcja_pojazdow/data_1024_res/images/test/2008-11-27-Muenchen-Verkehr-links-ys5z0038__1024__768___0.jpg: 1 duplicate labels removed
# val: /home/bartos/projekty_yolo/detekcja_pojazdow/data_1024_res/images/test/2008-11-27-Muenchen-Verkehr-links-ys5z0038__1024__768___1536.jpg: 1 duplicate labels removed
# ...
